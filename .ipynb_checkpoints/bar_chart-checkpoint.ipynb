# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
 
cities = ('Bogor', 'Bandung', 'Jakarta', 'Semarang', 'Yogyakarta', 
          'Surakarta','Surabaya', 'Medan', 'Makassar')
 
populations = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085,
               3481, 287750, 785409)
 
# plt.bar(x=cities, height=populations)

# #Merapikan sumbu x dengan menggeser rotasi elemen sumbu x
# plt.xticks(rotation = -45)
# plt.show()

# #Merapikan barchartS dengan memutar histogram

# plt.barh(y=cities, width = populations)
# plt.show()

#Menggabungkan modifikasi dengan fitur sort_values
df = pd.DataFrame(
    {
        'Cities' : cities,
        'Population' : populations,
    }
)

# df.sort_values(by = "Population", inplace = True)
# plt.barh(y = df['Cities'], width = df['Population'])

# #Menambahkan hiasan
# plt.xlabel("Populasi (dalam jutaan)")
# plt.ylabel("Kota")
# plt.title("Populasi kota di Indonesia")
# plt.show()

#Barchart menggunakan library seaborn
sns.barplot(y = df['Cities'],  x = df['Population'], orient = 'h', color ='red')
plt.xlabel("Populasi (dalam jutaan)")
plt.ylabel("Kota")
plt.title('Populasi kota di Indonesia')
plt.show()
