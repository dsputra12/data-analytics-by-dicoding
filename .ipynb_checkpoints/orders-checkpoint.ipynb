# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Data yang belum dibersihkan
print("Data yang belum dibersihkan:\n")

#Customers
df = pd.read_csv('customers.csv')

#Menampikkan hasil tabel untuk 5 baris pertama
tabel_customer = df.head()

#Memberikan informasi terkait tabel customers secara keseluruhan
info_customer = df.info()
# print(tabel_customer)
print(info_customer)

#Mencari data kosong
total_customer_kosong = df.isna().sum()
print(total_customer_kosong)

# #Mencari data yang duplikat
# customer_duplikat = df.duplicated().sum()
# print("Customer duplikat: ", customer_duplikat)

# #Menampilkan deskripsi statistik (khusus data numerik)
# deskripsi_customer = df.describe()
# print(deskripsi_customer)

#Menghapus data yang duplikat
#Keterangan: inplace = True akan memodifikasi tabel secara langsung, dan hanya bisa dipanggil lagi menggunakan data yang lama, tanpa mengembalikan luaran
new_customer = df.drop_duplicates(inplace = False)
new_customer_duplikat = new_customer.duplicated().sum()
print("Customer yang duplikat setelah dibersihkan: ", new_customer_duplikat)

# #Filter data untuk melihat data gender pada Customer yang kosong
# gender_kosong = df[df.gender.isna()]
# print(gender_kosong)

#Cek isi elemen pada kolom / variabel tertentu 
isi_gender = df.gender.value_counts()
print(isi_gender)

#Mengganti nilai yang kosong dengan element tertentu
gender_full = df.gender.fillna(value ="Non Binary", inplace = False)
isi_gender_bersih = gender_full.value_counts()
print("Customer yang kosong setelah dibersihkan:\n", isi_gender_bersih)
df.info()








# #Orders
# df2 = pd.read_csv('orders.csv')
# tabel_orders = df2.head()
# # print(tabel_orders)

# #Memberikan informasi terkait tabel orders secara keseluruhan
# info_orders = df2.info()
# print(info_orders)

# #Cek duplikasi data
# orders_duplikat = df2.duplicated().sum()
# print(orders_duplikat)

# #Deskripsi statistik data Orders
# deskripsi_orders = df2.describe()
# print(deskripsi_orders)

#Products
# df3 = pd.read_csv('products.csv')
# tabel_products = df3.head()
# print(tabel_products)

# #Menampilkan informasi terkait data Products secara keseluruhan
# info_products = df3.info()
# print(info_products)

# #Cek duplikasi products
# products_duplikat = df3.duplicated().sum()
# print(products_duplikat)

# #Deskripsi statistik dari data Products
# deskripsi_products = df3.describe()
# print(deskripsi_products)

# #Sales
# df4 = pd.read_csv('sales.csv')
# tabel_sales = df4.head()
# print(tabel_sales)

# #Memberikan info terkait Sales secara keseluruhan
# info_sales = df4.info()
# print(info_sales)

# #Mencari data kosong
# sales_kosong = df4.isna().sum()
# print(sales_kosong)

# #Cek duplikasi data Sales
# sales_duplikat = df4.duplicated().sum()
# print(sales_duplikat)

# #Memberikan deskripsi statistik terkait Sales
# deskripsi_sales = df4.describe()
# print(deskripsi_sales)

# #Data yang sudah dibersihkan
# print("Data yang sudah dibersihkan:")
# Out:
# Data yang belum dibersihkan:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB
# None
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64
# gender
# Prefer not to say    731
# Male                 143
# Female               115
# ...
