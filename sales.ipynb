# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Data yang belum dibersihkan
print("Data yang belum dibersihkan:\n")

#Sales
df = pd.read_csv('sales.csv')

#Informasi tabel sales
info_sales = df.info()
print(info_sales)

#Mencari kolom yang kosong
sales_kosong = df.isna().sum()
print(sales_kosong)

#Mencari info lebih lanjut terkait kolom yang kosong
daftar_kosong = df[df.total_price.isna()]
print(daftar_kosong)

#Pemberersihan data kosong dengan mengisinya dengan nilai produtct * quantity
df['total_price'] = df['price_per_unit'] * df['quantity']

sales_kosong = df.isna().sum()
print(sales_kosong)

#Cara mengecek salah satu nilai di elemen tertentu pada kolom tertentu
print(df[df['sales_id'] == 9]['total_price'])
# Out:
# Data yang belum dibersihkan:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB
# None
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# ...
